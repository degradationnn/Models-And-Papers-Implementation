# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os

sys.path.append('../Model_Selection')

from Model_Selection import KFolds, learning_curve, f1_score, r2_score, mean_squared_error, mean_absolute_error, accuracy_score


np.random.seed(42)

# Create a linearly spaced array of 1000 points between 0 and 10 with some noise

a1 = 3.5
b = 2.5
a2 = 8.2

x1 = np.random.uniform(20, 100, 10000)
x2 = np.random.uniform(0, 10, 10000)
y = a1 * x1 + a2 * x2 + b + np.random.normal(0, 1, 10000)

x = np.array([x1, x2]).T

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'Preprocessing')))
from LinearModels import LinearRegression
from Preprocessing import Train_And_Test

X_train, X_test, y_train, y_test = Train_And_Test(x, y)

Model = LinearRegression()

Model.fit(X_train, y_train)
y_predict = Model.predict(X_test)


plt.scatter(X_test[:, 0], y_predict)
plt.plot()
plt.scatter(X_test[:, 1], y_predict)
plt.plot()


print(Model.score(X_test, y_test))
# Out:
# {'MSE': 0.9867203861459531, 'RMSE': 0.9933380019640612, 'MAE': 0.794040440911025, 'R2': 0.9998601876677098}

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'Preprocessing')))
from LinearModels import SGDRegression
from Preprocessing import Train_And_Test, MinMaxScaler

mms = MinMaxScaler()
x = mms.fit_transform(x)

X_train, X_test, y_train, y_test = Train_And_Test(x, y)

Model = SGDRegression(n_iters = 100)

Model.fit(X_train, y_train)

y_predict = Model.predict(X_test)


plt.scatter(X_test[:, 0], y_predict)
plt.plot()
plt.scatter(X_test[:, 1], y_predict)
plt.plot()


print(Model.score(X_test, y_test))
# Out:
# {'MSE': 1.058349423646558, 'RMSE': 1.0287611110683363, 'MAE': 0.8242711403886452, 'R2': 0.9998507244674917}

# %%
# Create a linearly spaced array of 1000 points between 0 and 10 with some noise

a = 3.5
b = 2.5

x = np.linspace(0, 10, 10000)
y = a * x + b + np.random.normal(0, 1, 10000)

x = pd.DataFrame(x)
y = pd.DataFrame(y)

print(x)
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of y = 3.5x + 2.5 + noise')

plt.show()
# Out:
#            0
# 0      0.000
# 1      0.001
# 2      0.002
# 3      0.003
# 4      0.004
# ...      ...
# 9995   9.996
# 9996   9.997
# 9997   9.998
# 9998   9.999
# 9999  10.000
#
# [10000 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


np.random.seed(42)

# Create a linearly spaced array of 1000 points between 0 and 10 with some noise

a = 3.5
b = 2.5
c = 10
d = 1
e = 9

x = np.linspace(1, 10, 10000)
y = a * x ** 4 + b * x ** 3 + c * x ** 2 + d * x + e + np.random.normal(0, 0.1, 10000)

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'Preprocessing')))
from Preprocessing import PolynomialFeatures, Train_And_Test

poly = PolynomialFeatures(4, False)


x_poly = poly.fit_transform(x)


X_train, X_test, y_train, y_test = Train_And_Test(x_poly, y)


Model = LinearRegression()

Model.fit(X_train, y_train)

y_predict = Model.predict(X_test)



print(Model.score(X_test, y_test))
# Out:
# {'MSE': 0.010257753302823495, 'RMSE': 0.101280567251687, 'MAE': 0.08109411872935003, 'R2': 0.9999999999073611}

# %%
from LinearModels import RidgeRegression

poly = PolynomialFeatures(4, False)


x_poly = poly.fit_transform(x)


X_train, X_test, y_train, y_test = Train_And_Test(x_poly, y)


Model = RidgeRegression()

Model.fit(X_train, y_train)

y_predict = Model.predict(X_test)



print(Model.score(X_test, y_test))
# Out:
# {'MSE': 0.010608097105529344, 'RMSE': 0.10299561692387373, 'MAE': 0.08193068829851975, 'R2': 0.9999999999052244}

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(42)

# Create a linearly spaced array of 1000 points between 0 and 10 with some noise

a1 = 3.5
b = 2.5
a2 = 8.2

x1 = np.random.uniform(0, 1, 10000)
x2 = np.random.uniform(0, 1, 10000)
y = a1 * x1 + a2 * x2 + b + np.random.normal(0, 1, 10000)

x = np.array([x1, x2]).T

# %%
from LinearModels import LassoRegression   




X_train, X_test, y_train, y_test = Train_And_Test(x, y)


Model = LassoRegression( 0.001, 0.001, 1000)

Model.fit(X_train, y_train)

y_predict = Model.predict(X_test)

plt.plot(range(1000), Model.losses)


print(Model.score(X_test, y_test))
# Out:
# {'MSE': 6.84276188437348, 'RMSE': 2.615867329275986, 'MAE': 2.1622000477088346, 'R2': 0.09333052525311969}

# %%
from LinearModels import ElasticNet 






Model = ElasticNet( 0.01, 0.2, 0.01, 1000)

Model.fit(X_train, y_train)

y_predict = Model.predict(X_test)

plt.plot(range(1000), Model.losses)


print(Model.score(X_test, y_test))
# Out:
# {'MSE': 1.6970815403245738, 'RMSE': 1.3027208220968043, 'MAE': 1.0417258707518275, 'R2': 0.7751358216508231}

# %%
from LinearModels import LogisticRegression

# Générer des données X avec une relation linéaire avec y
n_samples = 1000
X = np.random.rand(n_samples, 1) * 10  # Générer des valeurs aléatoires pour X

# Générer la variable cible y avec une relation linéaire, plus un peu de bruit
y = (X[:, 0] > 5).astype(int)  # Si X > 0.5, y = 1, sinon y = 0
# Split the data into training and testing data
X_train, X_test, y_train, y_test = Train_And_Test(X, y,)

# Create a logistic regression model
logistic_model = LogisticRegression(alpha=0, n_iters=1000, learning_rate = 1)

# Fit the model on the training data
logistic_model.fit(X_train, y_train)

# Predict on the test data
y_pred = logistic_model.predict(X_test)

# Calculate the accuracy of the model
print(np.unique(y_pred))  # Pour voir les valeurs uniques dans les prédictions

print(logistic_model.score(X_test, y_test))
plt.scatter(X, logistic_model._sigmoid(np.dot(X, logistic_model.weights) + logistic_model.bias))
plt.scatter(X_test, y_pred)

plt.plot()
plt.show()
# Out:
# [0 1]
# {'Accuracy': 0.99, 'Recall': 1.0, 'Precision': 0.9805825242718447, 'F1 Score': 0.9901960784313726}
